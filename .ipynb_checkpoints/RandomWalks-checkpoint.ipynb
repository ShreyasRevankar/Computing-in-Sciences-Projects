# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
def random_walk(num_steps, x_start=0):
    a_steps = np.random.randint(2, size=num_steps)
    b_steps = a_steps * 2 - 1
    return x_start + np.cumsum(b_steps)

# %%
xi = np.zeros(100)
xi_sq = np.zeros(100)

all_pos =[]

for i in range(100):
    rw1 = random_walk(100)
    all_pos.append(rw1)
    xi += rw1
    xi_sq += (rw1*rw1)
    plt.plot(rw1)
    plt.xlabel('Step')
    plt.ylabel('Position')

# %%
plt.plot(xi/100)
plt.xlabel('time')
plt.ylabel('<x_i>')
# Out:
# Text(0, 0.5, '<x_i>')

# %%
plt.plot(xi_sq/100)
plt.xlabel('time')
plt.ylabel('<x_i^2>')
# Out:
# Text(0, 0.5, '<x_i^2>')

# %%
plt.plot(xi_sq/100 - ((xi)/100)*((xi)/100))
plt.xlabel('x_i')
plt.ylabel('Variance')
# Out:
# Text(0, 0.5, 'Variance')

# %%
## Doing the same thing but better

# %%
r_walks = np.array(all_pos)
num_walks = 100

# %%
r_walks
# Out:
# array([[  1,   2,   3, ...,   4,   3,   2],
#        [ -1,   0,   1, ...,  12,  11,  12],
#        [ -1,   0,   1, ...,  12,  11,  12],
#        ...,
#        [  1,   2,   1, ..., -10, -11, -10],
#        [  1,   2,   3, ...,   2,   1,   2],
#        [ -1,  -2,  -1, ...,   4,   5,   4]])

# %%
plt.plot(np.sum(r_walks, axis=0) / num_walks)
plt.xlabel('Time')
plt.ylabel('Average position')
# Out:
# Text(0, 0.5, 'Average position')

# %%
plt.plot(np.sum((r_walks * r_walks), axis=0) / num_walks)
plt.xlabel('Time')
plt.ylabel('<x_i^2>')
# Out:
# Text(0, 0.5, '<x_i^2>')

# %%
x_avg = np.sum(r_walks, axis = 0)/num_walks
x_avg
# Out:
# array([-0.06,  0.02,  0.1 ,  0.02,  0.12,  0.16,  0.22,  0.14,  0.04,
#         0.  ,  0.22,  0.08,  0.08, -0.12, -0.2 ,  0.06,  0.1 , -0.1 ,
#         0.04,  0.22,  0.14,  0.18,  0.22,  0.2 ,  0.16,  0.18,  0.3 ,
#         0.14,  0.28,  0.34,  0.46,  0.44,  0.36,  0.3 ,  0.26,  0.32,
#         0.42,  0.46,  0.52,  0.46,  0.64,  0.66,  0.74,  0.62,  0.58,
#         0.56,  0.58,  0.5 ,  0.58,  0.56,  0.56,  0.6 ,  0.56,  0.68,
#         0.62,  0.5 ,  0.44,  0.52,  0.4 ,  0.44,  0.34,  0.26,  0.22,
#         0.16,  0.22,  0.06,  0.1 ,  0.02,  0.06,  0.16,  0.2 ,  0.24,
#         0.2 ,  0.12,  0.2 ,  0.3 ,  0.2 ,  0.3 ,  0.36,  0.3 ,  0.28,
#         0.32,  0.38,  0.36,  0.24,  0.18,  0.12,  0.12,  0.26,  0.32,
#         0.28,  0.38,  0.18,  0.16,  0.2 ,  0.3 ,  0.48,  0.52,  0.56,
#         0.66])

# %%
dx2 = np.sum((r_walks - x_avg)**2, axis=0)/num_walks
plt.plot(dx2)

# %%
a12 = np.zeros(9) + 5
a12
# Out:
# array([5., 5., 5., 5., 5., 5., 5., 5., 5.])

# %%
trap = 10
frac = 0
for i in range(num_walks):
    w_a = np.where(r_walks[i]==trap)
#     print(w_a) 
    if(w_a[0].shape[0] > 0):
        frac += 1
        print(i, w_a[0][0])
        r_walks[i][w_a[0][0]:100] = np.zeros(100 - w_a[0][0]) + trap
# Out:
# 0 43
# 1 39
# 2 55
# 6 99
# 9 45
# 11 39
# 14 41
# 16 19
# 24 23
# 25 35
# 29 69
# 34 23
# 41 71
# 47 25
# 56 71
# 57 33
# 58 35
# 62 35
# 69 19
# 70 57
# 76 69
# 80 65
# 81 31
# 82 19
# 83 57
# 86 43
# 87 99
# 93 77

# %%
# r_walks
for i in range(num_walks):
    plt.plot(r_walks[i])

# %%
print("Fraction of trapped trajectories =", frac / 100)
# Out:
# Fraction of trapped trajectories = 0.28
